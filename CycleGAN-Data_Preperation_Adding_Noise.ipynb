# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive

# %%
# %cd '/gdrive/My Drive/CYCLEGAN'

# %%
# !ls

# %% [markdown]
# [Kaggle Signature Dataset](https://www.kaggle.com/robinreni/signature-verification-dataset)

# %% [markdown]
# # Code for generating noisy signature images

# %%
import os
os.sys.path
import os, sys, random, shutil
import xml.etree.ElementTree as ET
from glob import glob
import numpy as np
from cv2 import cv2
from shutil import copyfile
import pandas as pd
from sklearn import preprocessing, model_selection
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import patches

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.5.62-cp36-abi3-win_amd64.whl (35.4 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\deger\anaconda3\envs\ml\lib\site-packages (from opencv-python) (1.21.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.62

# %%
def add_random_straight_lines(image,height, width):
    ''' Add random straight lines to the image '''
    num_lines = np.random.randint(1, 5) # number of lines to be added
    y0 = int(height/num_lines) # gap/width between each lines
    for i in range(num_lines):
        line_thickness = np.random.randint(1, 5)
        x1, x2 = 0, width # starting and ending x coordinates
        y = y0*(i+1) + np.random.randint(-0.05*height, 0.05*height) # y coordinate of line
        image = cv2.line(image, (x1, y), (x2, y), (0, 0, 0), thickness=line_thickness) #draw line
        prev_y = y
    return image

# %%
def add_random_text(image, height, width):
    ''' Add random texts to the image '''
    closings = ['Sincerly', 'Regards', 'Yours truly', 'Best regards', 'Cordially']
    bottom_text = ['Amal Joseph', 'Steve Jobs', 'Larry Page', 'Paul Walker', 'Raja Ravi Varma', 'Katie Bouman', 'Ada Loveless']

    font = [cv2.FONT_HERSHEY_DUPLEX, cv2.FONT_HERSHEY_COMPLEX, cv2.FONT_HERSHEY_TRIPLEX, cv2.FONT_HERSHEY_COMPLEX_SMALL]
    y = np.random.randint(0.75*height, 1.02*height)
    x = np.random.randint(0.0005*width, 0.3*width)
    fontScale = np.random.random() + 0.7
    thickness = np.random.randint(1, 3)
    image = cv2.putText(image, np.random.choice(bottom_text), (x, y), np.random.choice(font), fontScale, (0, 0, 0), thickness, cv2.LINE_AA)
    return image

# %%
def process_image(image_path):    
    ''' Add random straight lines and texts to the image '''
    image = cv2.imread(image_path)
    height, weight, _ = image.shape
    image = add_random_text(image, height, width)
    image = add_random_straight_lines(image, height, width)
    return image

# %%
# usage example
image = cv2.imread(imagepath)
height, width, _ = image.shape
image = process_image(image, height, width)
plt.imshow(image)


'''
# usage example
imagepath = '/gdrive/My Drive/Signature/Signature-Verification_System_using_YOLOv5-and-CycleGAN-master/Training/CycleGAN/signData/train/069_forg/04_0111069.PNG'
image = cv2.imread(imagepath)
height, width, _ = image.shape
image = process_image(image, height, width)
plt.imshow(image)
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12264/3691655489.py in <module>
#       1 # usage example
# ----> 2 image = cv2.imread(imagepath)
#       3 height, width, _ = image.shape
#       4 image = process_image(image, height, width)
#       5 plt.imshow(image)
#
# NameError: name 'imagepath' is not defined

# %% [markdown]
# # Convert Dataset to CycleGAN Folder Structure
# CycleGAN perform image (domainA) to image (domainB) translation. Train and test images of domainA (clean signatures) must be stored in folders trainA and testA respectively. Similarily, the images in domainB (noisy) should be stored in trainB and testB
#
# Note: I moved all the signatures (from all the subfolders in train and test directory) in Kaggle dataset into one single directory, and the following operations are performed on the resultant folder which contains all the signatures.
# Used only the real signatures from the dataset.

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 3CFD-EB4C
#
#  Directory of C:\Users\Deger\Desktop\Cyclegan
#
# 03.03.2022  15:58    <DIR>          .
# 03.03.2022  15:58    <DIR>          ..
# 03.03.2022  15:58    <DIR>          .ipynb_checkpoints
# 11.02.2022  15:53    <DIR>          2
# 11.02.2022  15:24    <DIR>          3
# 03.03.2022  15:54            13.518 CycleGAN-Data_Preperation_Adding_Noise.ipynb
# 03.03.2022  16:12    <DIR>          gan_signdata_kaggle
# 03.03.2022  15:46    <DIR>          gan_signdata_kaggle (copy)
# 03.03.2022  16:12    <DIR>          gan-sign_data_kaggle
# 04.06.2021  00:05             7.485 README.md
# 03.03.2022  15:58             5.653 SignatureCleaningCycleGAN.ipynb
#                3 File(s)         26.656 bytes
#                8 Dir(s)  25.900.625.920 bytes free

# %%
# move images from sub directories to another folder
root_path = 'sign_data_local/images/'

for root, dirs, files in os.walk(root_path):
    for filename in files:
        shutil.move(os.path.join(root, filename), 'gan-sign_data_local/A/')

# %%
height = 512
width = 512
# apply image augumentations and save them
root_path = 'gan-sign_data_local/images/'
for root, dirs, files in os.walk(root_path):
    for filename in files:
        image = process_image(os.path.join(root, filename))
        cv2.imwrite(f'gan-sign_data_local/B/{filename}', image)
#         shutil.move(os.path.join(root, filename), 'gan-sign_data_local/images/')

# %%
# splitting into train and test
srcA_path = 'gan-sign_data_local/A/'
srcB_path = 'gan-sign_data_local/B/'

trainA_path = 'sign_data_result/trainA/'
testA_path = 'sign_data_result/testA/'


trainB_path = 'sign_data_result/trainB/'
testB_path = 'sign_data_result/testB/'

# %%
def split_data(src_path, train_path, test_path, split_ratio):
    files = np.array(os.listdir(src_path))
    np.random.shuffle(files)
    split_index = int(split_ratio * len(files))
    testA = files[0:split_index]
    trainA = files[split_index:]
    [shutil.move(os.path.join(src_path, path), os.path.join(train_path, path)) for path in trainA]
    [shutil.move(os.path.join(src_path, path), os.path.join(test_path, path)) for path in testA]

split_data(srcA_path, trainA_path, testA_path, 0.1)
split_data(srcB_path, trainB_path, testB_path, 0.1)

# %%
os.rmdir(srcA_path)
os.rmdir(srcB_path)
os.rmdir('gan-sign_data_local/images/')

# %% [markdown]
# # Transforming images to CycleGAN input format
# CycleGAN requires images of same shape, so I decided to train it with 512x512 images with signature at the center and black (transparent) strips at top and bottom.

# %%
# to find the maximum width and height present in the images
from PIL import Image
import os, sys
size_images = dict()
#width = 512
#height = 512

for dirpath, _, filenames in os.walk(trainA_path):
width': 552, 'heigth': 90}, '003_10.PNG': {'width': 412, 'heigth': 101}, '003_11.PNG': {'width': 582, 'heigth': 104}, '003_12.PNG': {'width': 514, 'heigth': 98}, '003_13.PNG': {'width': 500, 'heigth': 92}, '003_14.PNG': {'width': 529, 'heigth': 103}, '003_15.PNG': {'width': 593, 'heigth': 106}, '003_16.PNG': {'width': 542, 'heigth': 119}, '003_17.PNG': {'width': 540, 'heigth': 98}, '003_18.PNG': {'width': 595, 'heigth': 106}, '003_19.PNG': {'width': 504, 'heigth': 110}, '003_20.PNG': {'width': 510, 'heigth': 97}, '003_21.PNG': {'width': 521, 'heigth': 99}, '003_22.PNG': {'width': 520, 'heigth': 114}, '003_23.PNG': {'width': 572, 'heigth': 97}, '003_24.PNG': {'width': 615, 'heigth': 91}, '004_01.PNG': {'width': 290, 'heigth': 206}, '004_02.PNG': {'width': 244, 'heigth': 194}, '004_03.PNG': {'width': 292, 'heigth': 242}, '004_04.PNG': {'width': 251, 'heigth': 215}, '004_05.PNG': {'width': 259, 'heigth': 226}, '004_06.PNG': {'width': 316, 'heigth': 218}, '004_07.PNG': {'width': 272, 'heigth': 240}, '004_09.PNG': {'width': 307, 'heigth': 192}, '004_10.PNG': {'width': 269, 'heigth': 221}, '004_11.PNG': {'width': 260, 'heigth': 188}, '004_12.PNG': {'width': 293, 'heigth': 224}, '004_13.PNG': {'width': 281, 'heigth': 198}, '004_14.PNG': {'width': 239, 'heigth': 206}, '004_15.PNG': {'width': 229, 'heigth': 221}, '004_16.PNG': {'width': 299, 'heigth': 176}, '004_17.PNG': {'width': 297, 'heigth': 238}, '004_18.PNG': {'width': 306, 'heigth': 152}, '004_19.PNG': {'width': 248, 'heigth': 177}, '004_21.PNG': {'width': 268, 'heigth': 178}, '004_22.PNG': {'width': 315, 'heigth': 221}, '004_23.PNG': {'width': 329, 'heigth': 253}, '006_01.PNG': {'width': 533, 'heigth': 233}, '006_03.PNG': {'width': 440, 'heigth': 223}, '006_04.PNG': {'width': 500, 'heigth': 218}, '006_05 ...

# %%
import os
from PIL import Image
im_size = 512
def make_square(image, min_size=512, fill_color=(255, 255, 255, 0)):
    ''' Resize image as a square with signature in the center and black(transparent) strips at top and bottom. '''
    x, y = image.size
    size = max(min_size, x, y)
    new_im = Image.new('RGBA', (size, size), fill_color)
    new_im.paste(image, (int((size - x) / 2), int((size - y) / 2)))
    new_im = new_im.resize((im_size, im_size))
    return new_im

def resize_images(path):
    ''' Function to resize the images to the ip format for gans. '''
    dirs = os.listdir(path)
    for item in dirs:
        if os.path.isfile(path+item):
            image = Image.open(path+item)
            image = make_square(image)
            image.save(path+item)

resize_images(trainA_path)
resize_images(trainB_path)
resize_images(testA_path)
resize_images(testB_path)
